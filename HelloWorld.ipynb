# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
slices = [30,20,10,40]
labels = ['Thirty', 'Twenty','Ten','Forty']

plt.pie(slices, labels=labels)

plt.title("Data Visualization of Numbers")
plt.tight_layout()
plt.show()
